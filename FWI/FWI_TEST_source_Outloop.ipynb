# %% [markdown]
# # 1 Import Library

# %%
# %reset -f

# %%
import plotting
from pyseis.wave_equations import elastic_isotropic, acoustic_isotropic
from pyseis.wavelets.elastic import Elastic2D
from pyseis.wavelets.acoustic import Acoustic2D
from pyseis import inversion
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage, interpolate

import os
import math
pwd = os.getcwd()
# %env DATAPATH={pwd}/wrk/
# Out:
# WARNING! DATAPATH not found. The folder /tmp will be used to write binary files
# env: DATAPATH=/home/test01/App/01_PySeis/xu/TASK6_DAS_DATA/Data/FWI/wrk/

# %% [markdown]
# # 2 Read Model

# %%
dir_model = "./model/"
dir_seis  = "./seis/"
ox, oz = 0.0, 0.0
dx, dz = 1.0, 1.0
x1, x2 = 0.0, 550.0
z1, z2 = 0.0, 900.0


x_grid = np.arange(x1, x2 + dx, dx)
z_grid = np.arange(z1, z2 + dz, dz)
nx, nz = x_grid.size, z_grid.size
print("Grid dimensions: ", nx, nz)
model_sampling = (dx, dz)

model_padding = (100,100)
### Read (dx, dz) = (2, 2) model
vp2d_true = np.fromfile(dir_model+"vp2d_true.bin", dtype="float32")
vp2d_init = np.fromfile(dir_model+"vp2d_init.bin", dtype="float32")

vp2d_true = vp2d_true.reshape(nx,nz)
vp2d_init = vp2d_init.reshape(nx,nz)
# Out:
# Grid dimensions:  551 901

# %%
# ---- Receiver geometry ----
drec = 1.0
recz1 = 1.0
recz2 =884
recx1 = 200.0
recz = np.arange(recz1, recz2, drec)
recx = np.full(recz.shape, recx1)
recs = np.column_stack([recx, recz])

# ---- Source geometry ----
srcx = np.array([182.3])
srcz = np.full(srcx.shape, 1.0)
srcs = np.column_stack([srcx, srcz])


# Sampling in the x and z directions (5m for both in this case)
model_sampling = (dx, dz)
# Origin of the model (0, 0)
model_origins = (ox, oz)

# %%
# ---- Plot ----
plotting.plot_model(
    vp2d_true,
    title="True Vp (Horizontally Homogeneous, Original Interval Velocity)",
    cbar=True,
    sampling=(dx, dz),
    origins=(ox, oz),
    cmap='jet',
    cbar_label='$v_p$ (m/s)',
    src_locations=srcs,
    rec_locations=recs,
    figsize=(12, 6),
    vlims=[1000, 2200]
)

# %%
plotting.plot_model(
    vp2d_init,
    title="True Vp (Horizontally Homogeneous, Original Interval Velocity)",
    cbar=True,
    sampling=(dx, dz),
    origins=(ox, oz),
    cmap='jet',
    cbar_label='$v_p$ (m/s)',
    src_locations=srcs,
    rec_locations=recs,
    figsize=(12, 6),
    vlims=[1000, 2200]
)

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------- params --------
file_path1 = "source_pilot_run3_raw.bin"
nt = 3001       # original samples
dt = 0.001
nt_new = 2000   # cut down to 2000 samples

# -------- load raw --------
data1 = np.fromfile(file_path1, dtype=np.float32).astype(np.float64, copy=False)
if len(data1) < nt:
    raise ValueError(f"File has {len(data1)} samples, but nt={nt} requested.")
data1_raw = data1[:nt_new]   # keep only 2000 samples

# time axis
time_axis = np.arange(nt_new) * dt

# -------- scale --------
g = 0.1608
new_source = data1_raw.copy()        # original cut
scaled_source = g * data1_raw        # scaled version

# -------- spectrum helper --------
def one_sided_spectrum(x, dt):
    X = np.fft.rfft(x)
    f = np.fft.rfftfreq(len(x), d=dt)
    return f, np.abs(X)

f_src_raw, A_src_raw = one_sided_spectrum(new_source, dt)
f_src_scaled, A_src_scaled = one_sided_spectrum(scaled_source, dt)


source_form = np.pad(data1_raw, (0, nt_new - len(data1_raw)), mode="constant")

source_form_scale = g * np.pad(data1_raw, (0, nt_new - len(data1_raw)), mode="constant")



# -------- plots --------
plt.figure(figsize=(12, 8))

# Time-domain (cut + scaled)
plt.subplot(2, 1, 1)
plt.plot(time_axis, new_source, label='Original (cut to 2000)')
plt.plot(time_axis, scaled_source, label=f'Scaled (g={g})', linestyle='--')
plt.title("Time-Domain Source")
plt.xlabel("Time (s)"); plt.ylabel("Amplitude")
plt.grid(True); plt.legend()

# Spectrum (raw vs scaled)
plt.subplot(2, 1, 2)
plt.plot(f_src_raw, A_src_raw, label='Spectrum (original)')
plt.plot(f_src_scaled, A_src_scaled, label=f'Spectrum (scaled, g={g})', linestyle='--')
plt.title("Amplitude Spectrum")
plt.xlabel("Frequency (Hz)"); plt.ylabel("|X(f)|")
plt.xlim(0, 200); plt.grid(True); plt.legend()

plt.tight_layout()
plt.show()

# %%
# make 2d elastic wave equation solver
acoustic_2d_obs_base = acoustic_isotropic.AcousticIsotropic2D(
    model=vp2d_true,
    model_sampling=model_sampling,
    model_padding=model_padding,
    wavelet=source_form_scale,
    d_t=dt,
    src_locations=srcs,
    rec_locations=recs,
    model_origins=model_origins,
    subsampling=40,
    gpus=[0])

# %%
# %%time
data_obs_base_p = acoustic_2d_obs_base.forward(vp2d_true)
# Out:
# CPU times: user 8.56 s, sys: 3.39 s, total: 11.9 s
# Wall time: 4.35 s

# %%
# %%time
data_cal_base_p = acoustic_2d_obs_base.forward(vp2d_init)
# Out:
# CPU times: user 8.77 s, sys: 2.94 s, total: 11.7 s
# Wall time: 4.25 s

# %%
import numpy as np
import matplotlib.pyplot as plt

# dimensions
nr, nt = 883, 2000
dt = 0.001  # sample interval [s]

# reload the binary file
shot0 = np.fromfile("./data/input_upgoing_FB_neartrace.bin", dtype=np.float32).reshape(nr, nt)

# build axes
time_axis = np.arange(nt) * dt
rec_axis = np.arange(nr)

# robust scaling for colormap
vmax = np.percentile(np.abs(shot0), 85)   # you can adjust 85 -> 90/95
vmin = -vmax

# plot
plt.figure(figsize=(6, 6))
plt.pcolormesh(rec_axis, time_axis, shot0.T,
               shading='nearest', cmap='seismic',
               vmin=vmin, vmax=vmax)
plt.gca().invert_yaxis()
plt.title("First Shot (reloaded)")
plt.xlabel("Receiver #")
plt.ylabel("Time (s)")
plt.colorbar(label="Amplitude")
plt.show()

# %%
# extend to 3D to fit with RTM process
shot0_cut_3d = shot0[np.newaxis, :, :]   # (1, 446, 2000)

# %% [markdown]
# # Amplitude Mismatch Problem

# %%
obs = np.squeeze(shot0_cut_3d)   # (446, 2000)
cal = np.squeeze(data_cal_base_p)   # (446, 2000)
res = obs - cal

vmax = np.percentile(np.abs(obs), 99)  # consistent scaling

plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.imshow(obs.T, aspect='auto', cmap='gray', vmin=-vmax, vmax=vmax)
plt.title("Observed"); plt.xlabel("receiver"); plt.ylabel("time sample")

plt.subplot(1,3,2)
plt.imshow(cal.T, aspect='auto', cmap='gray', vmin=-vmax, vmax=vmax)
plt.title("Calculated (init model)"); plt.xlabel("receiver")

plt.subplot(1,3,3)
plt.imshow(res.T, aspect='auto', cmap='gray', vmin=-vmax, vmax=vmax)
plt.title("Residual (obs - cal)"); plt.xlabel("receiver")

plt.tight_layout(); plt.show()

# %%
obs = np.squeeze(shot0_cut_3d)
cal = np.squeeze(data_cal_base_p)

# compute least-squares scale factor
scale = np.sum(obs * cal) / (np.sum(cal * cal) + 1e-12)

cal_scaled = scale * cal
print("Applied global scale:", scale)
# Out:
# Applied global scale: 0.0015704331007704087

# %% [markdown]
# # 5 FWI RUN

# %%
# afwi_test = inversion.Fwi(acoustic_2d_obs_base,
#                          shot0_cut_3d,
#                          vp2d_init,
#                          num_iter=2,
#                          solver_type='cg',
#                          stepper_type='parabolic',
#                          iterations_per_save=5,
#                          prefix='aFWI4d_flat_curved_p')

# %%
# %%time
# history = afwi_test.run()

# %%
vp2d_init.shape
# Out:
# (551, 901)

# %%
# plotting.plot_model(history['inv_mod'],
#                     title='Difference',
#                     cbar=True,
#                     sampling=model_sampling,
#                     origins=model_origins,
#                     cmap='seismic',
#                     src_locations=srcs,
#                     rec_locations=recs,
#                     figsize=(12,6),
#                     vlims=[1000,3500],
#                    )

# %%
# obj_func_original = history['obj']
# fig, ax = plt.subplots(1,figsize=(10,5))
# ax.plot(obj_func_original/obj_func_original.max(), label='original')
# _ = ax.set_xlabel('iterations')
# _ = ax.set_ylabel('norm objective function')
# ax.legend()
# ax.grid()

# %%
import numpy as np

vmin, vmax = 500.0, 6000.0
vp_curr = np.clip(vp2d_init, vmin, vmax)

N_outer = 20
for k in range(N_outer):
    afwi_step = inversion.Fwi(
        acoustic_2d_obs_base,
        shot0_cut_3d,                    # (1, 446, 2000)
        vp_curr,                  # (551, 901)
        num_iter=1,               # one CG step per outer loop
 #       solver_type='cg',
        solver_type='lbfgs',
        stepper_type='parabolic',
        iterations_per_save=1,
        prefix=f'aFWI4d_flat_curved_p_iter{k+1:02d}'
    )

    history = afwi_step.run()     # dict with keys: inv_mod, gradient, model, residual, obj

    # <-- Use inv_mod: correct shape for the solver
    vp_next = history["inv_mod"]            # (551, 901)
    vp_curr = np.clip(vp_next, vmin, vmax)  # enforce physical bounds

    # (optional) mild smoothing for stability
    # from scipy.ndimage import uniform_filter
    # vp_curr = uniform_filter(vp_curr, size=3)

    print(f"[Outer {k+1}/{N_outer}] vp range: {vp_curr.min():.1f}–{vp_curr.max():.1f} m/s")

vp2d_final = vp_curr
# Out:
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-07-02.572755/
# ##########################################################################################
#
# iter = 0, obj = 2.32387e-02, resnorm = 2.16e-01, gradnorm = 3.19e-06, feval = 1, geval = 1
# iter = 1, obj = 1.72611e-02, resnorm = 1.86e-01, gradnorm = 1.71e-06, feval = 4, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 1/20] vp range: 1504.4–2623.8 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-08-02.206559/
# ##########################################################################################
#
# iter = 0, obj = 1.82592e-02, resnorm = 1.91e-01, gradnorm = 1.81e-06, feval = 1, geval = 1
# iter = 1, obj = 1.60736e-02, resnorm = 1.79e-01, gradnorm = 1.35e-06, feval = 4, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 2/20] vp range: 1451.6–2743.3 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-09-02.539421/
# ##########################################################################################
#
# iter = 0, obj = 1.65375e-02, resnorm = 1.82e-01, gradnorm = 1.38e-06, feval = 1, geval = 1
# iter = 1, obj = 1.58890e-02, resnorm = 1.78e-01, gradnorm = 1.12e-06, feval = 4, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 3/20] vp range: 1463.9–2986.7 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-10-03.144825/
# ##########################################################################################
#
# iter = 0, obj = 1.61014e-02, resnorm = 1.79e-01, gradnorm = 1.15e-06, feval = 1, geval = 1
# iter = 1, obj = 1.54461e-02, resnorm = 1.76e-01, gradnorm = 9.41e-07, feval = 4, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 4/20] vp range: 1388.8–3248.1 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-11-03.716328/
# ##########################################################################################
#
# iter = 0, obj = 1.56908e-02, resnorm = 1.77e-01, gradnorm = 9.60e-07, feval = 1, geval = 1
# iter = 1, obj = 1.53316e-02, resnorm = 1.75e-01, gradnorm = 8.23e-07, feval = 4, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 5/20] vp range: 1366.4–3456.5 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-12-03.986006/
# ##########################################################################################
#
# iter = 0, obj = 1.54581e-02, resnorm = 1.76e-01, gradnorm = 8.35e-07, feval = 1, geval = 1
# iter = 1, obj = 1.51984e-02, resnorm = 1.74e-01, gradnorm = 7.32e-07, feval = 4, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 6/20] vp range: 1260.6–3652.6 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-13-04.064003/
# ##########################################################################################
#
# iter = 0, obj = 1.53458e-02, resnorm = 1.75e-01, gradnorm = 7.45e-07, feval = 1, geval = 1
# iter = 1, obj = 1.50851e-02, resnorm = 1.74e-01, gradnorm = 6.76e-07, feval = 4, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 7/20] vp range: 1185.6–3772.0 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-14-03.953518/
# ##########################################################################################
#
# iter = 0, obj = 1.51562e-02, resnorm = 1.74e-01, gradnorm = 6.81e-07, feval = 1, geval = 1
# iter = 1, obj = 1.50210e-02, resnorm = 1.73e-01, gradnorm = 6.21e-07, feval = 4, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 8/20] vp range: 1092.1–3911.6 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-15-03.642606/
# ##########################################################################################
#
# iter = 0, obj = 1.50912e-02, resnorm = 1.74e-01, gradnorm = 6.28e-07, feval = 1, geval = 1
# iter = 1, obj = 1.48932e-02, resnorm = 1.73e-01, gradnorm = 5.82e-07, feval = 4, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 9/20] vp range: 885.9–4053.2 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-16-03.117510/
# ##########################################################################################
#
# iter = 0, obj = 1.49566e-02, resnorm = 1.73e-01, gradnorm = 5.86e-07, feval = 1, geval = 1
# iter = 1, obj = 1.49164e-02, resnorm = 1.73e-01, gradnorm = 5.56e-07, feval = 4, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 10/20] vp range: 908.5–4094.0 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-17-02.653402/
# ##########################################################################################
#
# iter = 0, obj = 1.49321e-02, resnorm = 1.73e-01, gradnorm = 5.59e-07, feval = 1, geval = 1
# iter = 1, obj = 1.47382e-02, resnorm = 1.72e-01, gradnorm = 5.19e-07, feval = 4, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 11/20] vp range: 573.5–4284.6 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-18-02.120817/
# ##########################################################################################
#
# iter = 0, obj = 1.48012e-02, resnorm = 1.72e-01, gradnorm = 5.24e-07, feval = 1, geval = 1
# iter = 1, obj = 1.48011e-02, resnorm = 1.72e-01, gradnorm = 5.24e-07, feval = 20, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 12/20] vp range: 573.5–4284.6 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-20-16.519763/
# ##########################################################################################
#
# iter = 0, obj = 1.48011e-02, resnorm = 1.72e-01, gradnorm = 5.24e-07, feval = 1, geval = 1
# iter = 1, obj = 1.48011e-02, resnorm = 1.72e-01, gradnorm = 5.24e-07, feval = 16, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 13/20] vp range: 573.6–4284.6 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-22-12.893682/
# ##########################################################################################
#
# iter = 0, obj = 1.48013e-02, resnorm = 1.72e-01, gradnorm = 5.24e-07, feval = 1, geval = 1
# iter = 1, obj = 1.48011e-02, resnorm = 1.72e-01, gradnorm = 5.24e-07, feval = 15, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 14/20] vp range: 573.7–4284.6 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-24-12.016776/
# ##########################################################################################
#
# iter = 0, obj = 1.48014e-02, resnorm = 1.72e-01, gradnorm = 5.24e-07, feval = 1, geval = 1
# iter = 1, obj = 1.48013e-02, resnorm = 1.72e-01, gradnorm = 5.24e-07, feval = 13, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 15/20] vp range: 574.0–4284.7 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-25-53.941157/
# ##########################################################################################
#
# iter = 0, obj = 1.48012e-02, resnorm = 1.72e-01, gradnorm = 5.24e-07, feval = 1, geval = 1
# iter = 1, obj = 1.48011e-02, resnorm = 1.72e-01, gradnorm = 5.24e-07, feval = 16, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 16/20] vp range: 574.1–4284.7 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-27-49.823875/
# ##########################################################################################
#
# iter = 0, obj = 1.48014e-02, resnorm = 1.72e-01, gradnorm = 5.24e-07, feval = 1, geval = 1
# iter = 1, obj = 1.48014e-02, resnorm = 1.72e-01, gradnorm = 5.23e-07, feval = 12, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 17/20] vp range: 574.4–4284.7 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-29-27.089627/
# ##########################################################################################
#
# iter = 0, obj = 1.48015e-02, resnorm = 1.72e-01, gradnorm = 5.23e-07, feval = 1, geval = 1
# iter = 1, obj = 1.48015e-02, resnorm = 1.72e-01, gradnorm = 5.23e-07, feval = 13, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 18/20] vp range: 574.8–4284.7 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-31-08.818853/
# ##########################################################################################
#
# iter = 0, obj = 1.48015e-02, resnorm = 1.72e-01, gradnorm = 5.23e-07, feval = 1, geval = 1
# iter = 1, obj = 1.48015e-02, resnorm = 1.72e-01, gradnorm = 5.23e-07, feval = 14, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 19/20] vp range: 575.2–4284.8 m/s
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm
# Restart folder: /tmp/restart_2025-09-19T03-32-55.711377/
# ##########################################################################################
#
# iter = 0, obj = 1.48016e-02, resnorm = 1.72e-01, gradnorm = 5.23e-07, feval = 1, geval = 1
# iter = 1, obj = 1.48015e-02, resnorm = 1.72e-01, gradnorm = 5.23e-07, feval = 16, geval = 2
# Terminate: maximum number of iterations reached
#
# ##########################################################################################
# Broyden-Fletcher-Goldfarb-Shanno (BFGS) algorithm end
# ##########################################################################################
#
# [Outer 20/20] vp range: 575.3–4284.8 m/s

# %%
plotting.plot_model(vp2d_final,
                    title='Difference',
                    cbar=True,
                    sampling=model_sampling,
                    origins=model_origins,
                    cmap='seismic',
                    src_locations=srcs,
                    rec_locations=recs,
                    figsize=(12,6),
                    vlims=[1200,3500],
                   )

# %%
plotting.plot_model(vp2d_final,
                    title='Velocity inverted',
                    cbar=True,
                    sampling=model_sampling,
                    origins=model_origins,
                    cmap='seismic',
                    src_locations=srcs,
                    rec_locations=recs,
                    figsize=(12,6),
                    vlims=[2200,2900],
                    xlims=(100, 300),
                    ylims=(850, 400)
                    # <<< restrict x-axis
)

# %%
plotting.plot_model(vp2d_final-vp2d_init,
                    title='Difference',
                    cbar=True,
                    sampling=model_sampling,
                    origins=model_origins,
                    cmap='seismic',
                    src_locations=srcs,
                    rec_locations=recs,
                    figsize=(12,6),
                    vlims=[-200,200],
                    xlims=(100, 300)   # <<< restrict x-axis
)

# %%
import numpy as np

# vp2d_final is your FWI velocity model (nz=551, nx=901)
vel = vp2d_final.astype(np.float32)

# save as raw binary file (z-fast layout, i.e. [z,x])
vel.tofile("vel_init_rtm.bin")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Choose x location (index, not meters)
x_location = 125  

# Extract 1D profiles
vp1d_base = vp2d_init[x_location, :]
vp1d_moni = vp2d_final[x_location, :]

# Depth axis
depth = np.linspace(model_origins[1],
                    model_origins[1] + model_sampling[1] * len(vp1d_base),
                    len(vp1d_base))

# Depth range
depth_min, depth_max = 0, 800
mask = (depth >= depth_min) & (depth <= depth_max)

vp1d_base = vp1d_base[mask]
vp1d_moni = vp1d_moni[mask]
depth = depth[mask]

# ---- single plot ----
plt.figure(figsize=(5,7))
plt.plot(vp1d_base, depth, label='Initial Vp', color='blue')
plt.plot(vp1d_moni, depth, label='FWI Vp', color='red', linestyle='--')
plt.gca().invert_yaxis()
plt.xlabel('$V_p$ (m/s)')
plt.ylabel('Depth (m)')
plt.title(f'Vp Comparison at x index {x_location}\nDepth {depth_min}-{depth_max} m')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
